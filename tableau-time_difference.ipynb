# %%
import pandas as pd

import csv

from datetime import datetime

citibike_df = pd.read_csv("March-May2020.csv")

citibike_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1               242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2               124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3               104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4               228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
# ...             ...                       ...                       ...
# 52059           395  2020-05-31 23:35:50.9460  2020-05-31 23:42:26.5300
# 52060          1681  2020-05-31 23:38:30.8240  2020-06-01 00:06:32.0360
# 52061          1657  2020-05-31 23:39:07.2680  2020-06-01 00:06:44.5740
# 52062           420  2020-05-31 23:45:28.3290  2020-05-31 23:52:28.3680
# 52063            87  2020-05-31 23:50:55.8390  2020-05-31 23:52:23.0920
#
#        start station id start station name  start station latitude  \
# ...

# %%
citibike_df.starttime
# Out:
# 0        2020-03-01 00:14:07.0000
# 1        2020-03-01 00:48:06.4390
# 2        2020-03-01 01:08:46.4880
# 3        2020-03-01 01:22:35.4790
# 4        2020-03-01 01:39:20.2680
#                    ...
# 52059    2020-05-31 23:35:50.9460
# 52060    2020-05-31 23:38:30.8240
# 52061    2020-05-31 23:39:07.2680
# 52062    2020-05-31 23:45:28.3290
# 52063    2020-05-31 23:50:55.8390
# Name: starttime, Length: 52064, dtype: object

# %%
citibike_df.stoptime
# Out:
# 0        2020-03-01 00:20:36.0880
# 1        2020-03-01 00:52:08.9870
# 2        2020-03-01 01:10:51.2780
# 3        2020-03-01 01:24:20.2470
# 4        2020-03-01 01:43:09.1380
#                    ...
# 52059    2020-05-31 23:42:26.5300
# 52060    2020-06-01 00:06:32.0360
# 52061    2020-06-01 00:06:44.5740
# 52062    2020-05-31 23:52:28.3680
# 52063    2020-05-31 23:52:23.0920
# Name: stoptime, Length: 52064, dtype: object

# %%
citibike_df['Timedifference']= pd.to_datetime(citibike_df['stoptime']) - pd.to_datetime(citibike_df['starttime'])
citibike_df['Timedifference']
# Out:
# 0       0 days 00:06:29.088000
# 1       0 days 00:04:02.548000
# 2       0 days 00:02:04.790000
# 3       0 days 00:01:44.768000
# 4       0 days 00:03:48.870000
#                  ...
# 52059   0 days 00:06:35.584000
# 52060   0 days 00:28:01.212000
# 52061   0 days 00:27:37.306000
# 52062   0 days 00:07:00.039000
# 52063   0 days 00:01:27.253000
# Name: Timedifference, Length: 52064, dtype: timedelta64[ns]

# %%
citibike_df['minutes'] =citibike_df['Timedifference'].dt.components['minutes']
citibike_df['minutes']
# Out:
# 0         6
# 1         4
# 2         2
# 3         1
# 4         3
#          ..
# 52059     6
# 52060    28
# 52061    27
# 52062     7
# 52063     1
# Name: minutes, Length: 52064, dtype: int64

# %%
citibike_df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1               242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2               124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3               104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4               228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
# ...             ...                       ...                       ...
# 52059           395  2020-05-31 23:35:50.9460  2020-05-31 23:42:26.5300
# 52060          1681  2020-05-31 23:38:30.8240  2020-06-01 00:06:32.0360
# 52061          1657  2020-05-31 23:39:07.2680  2020-06-01 00:06:44.5740
# 52062           420  2020-05-31 23:45:28.3290  2020-05-31 23:52:28.3680
# 52063            87  2020-05-31 23:50:55.8390  2020-05-31 23:52:23.0920
#
#        start station id start station name  start station latitude  \
# ...

# %%
len(citibike_df)
# Out:
# 52064

# %%
citibike_df.dropna()
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               389  2020-03-01 00:14:07.0000  2020-03-01 00:20:36.0880
# 1               242  2020-03-01 00:48:06.4390  2020-03-01 00:52:08.9870
# 2               124  2020-03-01 01:08:46.4880  2020-03-01 01:10:51.2780
# 3               104  2020-03-01 01:22:35.4790  2020-03-01 01:24:20.2470
# 4               228  2020-03-01 01:39:20.2680  2020-03-01 01:43:09.1380
# ...             ...                       ...                       ...
# 52059           395  2020-05-31 23:35:50.9460  2020-05-31 23:42:26.5300
# 52060          1681  2020-05-31 23:38:30.8240  2020-06-01 00:06:32.0360
# 52061          1657  2020-05-31 23:39:07.2680  2020-06-01 00:06:44.5740
# 52062           420  2020-05-31 23:45:28.3290  2020-05-31 23:52:28.3680
# 52063            87  2020-05-31 23:50:55.8390  2020-05-31 23:52:23.0920
#
#        start station id start station name  start station latitude  \
# ...

# %%
len(citibike_df)
# Out:
# 52064

# %%
citibike_df.to_csv("citibike.csv", index=False)
